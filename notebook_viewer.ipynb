# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('comments_data/entity_comments_details_20.csv')

# Check the first few rows to verify loading
df.head(100)
# Out:
#                     entity_id  \
# 0   do_1137277348012195841200
# 1   do_1137277348012195841200
# 2   do_1137277348012195841200
# 3   do_1137277348012195841200
# 4   do_1137277348012195841200
# ..                        ...
# 95  do_1137277348012195841200
# 96  do_1137277348012195841200
# 97  do_1137277348012195841200
# 98  do_1137277348012195841200
# 99  do_1137277348012195841200
#
#                                                                                  comment
# 0                                                                           informative
# 1   assessment m next question ka option nahi aa raha hai sir please solve this problem
# 2                                                                                  good
# 3                                                       it is very suggestion for future
# 4                                                                                   nice
# ...

# %%
# Set option to display full text (no truncation)
pd.options.display.max_colwidth = None

# Display the top 20 comments from the 'comment_data' column
df['comment'].head(50)
# Out:
# 0                                                                                                                                                     informative
# 1                                                                             assessment m next question ka option nahi aa raha hai sir please solve this problem
# 2                                                                                                                                                            good
# 3                                                                                                                                 it is very suggestion for future
# 4                                                                                                                                                             nice
# 5                                                                                                                                                       very nice
# ...
